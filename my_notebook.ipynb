# %%
# !pip freeze
# Out:
# anyio==4.4.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==24.2.0
# babel==2.16.0
# beautifulsoup4==4.12.3
# bleach==6.1.0
# certifi==2024.7.4
# cffi==1.17.0
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.2
# debugpy==1.8.5
# decorator==5.1.1
# defusedxml==0.7.1
# executing==2.0.1
# fastjsonschema==2.20.0
# fqdn==1.5.1
# h11==0.14.0
# httpcore==1.0.5
# httpx==0.27.0
# idna==3.7
# ipykernel==6.29.5
# ipython==8.26.0
# ipywidgets==8.1.3
# isoduration==20.11.0
# jedi==0.19.1
# Jinja2==3.1.4
# json5==0.9.25
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2023.12.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.10.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# jupyter_server==2.14.2
# jupyter_server_terminals==0.5.3
# jupyterlab==4.2.4
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.3
# jupyterlab_widgets==3.0.11
# MarkupSafe==2.1.5
# ...

# %% [markdown]
# install libraries

# %%
# Install TensorFlow, a popular machine learning framework
# TensorFlow is used for implementing machine learning models, especially neural networks
# It provides tools and libraries for building and training models, running computations on GPUs, etc.
# !pip install tensorflow
# Out:
# ^C
# ...
#   Using cached tensorflow-2.17.0-cp311-cp311-win_amd64.whl (2.0 kB)
# ...
#                                               0.0/385.0 MB ? eta -:--:--
#                                               0.0/385.0 MB ? eta -:--:--
#                                               0.0/385.0 MB ? eta -:--:--
#                                               0.0/385.0 MB ? eta -:--:--
#                                               0.0/385.0 MB ? eta -:--:--
#                                              0.0/385.0 MB 65.6 kB/s eta 1:37:46
#                                              0.0/385.0 MB 65.6 kB/s eta 1:37:46
#                                              0.0/385.0 MB 65.6 kB/s eta 1:37:46
#                                              0.0/385.0 MB 62.4 kB/s eta 1:42:47
#                                              0.0/385.0 MB 62.4 kB/s eta 1:42:47
#                                              0.0/385.0 MB 62.4 kB/s eta 1:42:47
# ...
